# %%
import pandas as pd # data processing, CSV file I/O
import numpy as np # linear algebra
import matplotlib 
import matplotlib.pyplot as plt
import sklearn
# %matplotlib inline 
plt.rcParams["figure.figsize"] = [16, 12]

# %%
df = pd.read_csv("./greenhouse_gas_inventory_data_data.csv", thousands=",")

# %%
df.head()
# Out:
#   country_or_area  year          value  \
# 0       Australia  2014  393126.946994
# 1       Australia  2013  396913.936530
# 2       Australia  2012  406462.847704
# 3       Australia  2011  403705.528314
# 4       Australia  2010  406200.993184
#
#                                             category
# 0  carbon_dioxide_co2_emissions_without_land_use_...
# 1  carbon_dioxide_co2_emissions_without_land_use_...
# 2  carbon_dioxide_co2_emissions_without_land_use_...
# 3  carbon_dioxide_co2_emissions_without_land_use_...
# 4  carbon_dioxide_co2_emissions_without_land_use_...

# %%
df.dtypes
# Out:
# country_or_area     object
# year                 int64
# value              float64
# category            object
# dtype: object

# %%
df['category'].unique()
# Out:
# array([ 'carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent',
#        'greenhouse_gas_ghgs_emissions_including_indirect_co2_without_lulucf_in_kilotonne_co2_equivalent',
#        'greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent',
#        'hydrofluorocarbons_hfcs_emissions_in_kilotonne_co2_equivalent',
#        'methane_ch4_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent',
#        'nitrogen_trifluoride_nf3_emissions_in_kilotonne_co2_equivalent',
#        'nitrous_oxide_n2o_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent',
#        'perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent',
#        'sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent',
#        'unspecified_mix_of_hydrofluorocarbons_hfcs_and_perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent'], dtype=object)

# %%
df['country_or_area'].unique()
# Out:
# array(['Australia', 'Austria', 'Belarus', 'Belgium', 'Bulgaria', 'Canada',
#        'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Estonia',
#        'European Union', 'Finland', 'France', 'Germany', 'Greece',
#        'Hungary', 'Iceland', 'Ireland', 'Italy', 'Japan', 'Latvia',
#        'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malta', 'Monaco',
#        'Netherlands', 'New Zealand', 'Norway', 'Poland', 'Portugal',
#        'Romania', 'Russian Federation', 'Slovakia', 'Slovenia', 'Spain',
#        'Sweden', 'Switzerland', 'Turkey', 'Ukraine', 'United Kingdom',
#        'United States of America'], dtype=object)

# %%
table = pd.pivot_table(df, values='value', index=['country_or_area', 'year'], columns=['category'])
table.head()
# Out:
# category              carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent  \
# country_or_area year
# Australia       1990                                      278265.898941
#                 1991                                      279741.639012
#                 1992                                      284766.092718
#                 1993                                      289142.267681
#                 1994                                      293830.709141
#
# category              greenhouse_gas_ghgs_emissions_including_indirect_co2_without_lulucf_in_kilotonne_co2_equivalent  \
# country_or_area year
# Australia       1990                                      418623.049563
#                 1991                                      418674.057494
#                 1992                                      423080.108191
#                 1993                                      423764.932564
#                 1994                                      424092.959373
#
# category              greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent  \
# country_or_area year
# Australia       1990                                      418623.049563
#                 1991                                      418674.057494
#                 1992                                      423080.108191
#                 1993                                      423764.932564
#                 1994                                      424092.959373
#
# category              hydrofluorocarbons_hfcs_emissions_in_kilotonne_co2_equivalent  \
# country_or_area year
# Australia       1990                                        1424.683520
#                 1991                                        1424.683520
#                 1992                                        1333.184000
#                 1993                                        1829.872000
#                 1994                                        1027.343549
#
# category              methane_ch4_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent  \
# country_or_area year
# Australia       1990                                      118768.837813
#                 1991                                      117744.641814
#                 1992                                      116837.506726
#                 1993                                      113837.511923
#                 1994                                      110997.410185
#
# category              nitrogen_trifluoride_nf3_emissions_in_kilotonne_co2_equivalent  \
# country_or_area year
# Australia       1990                                                NaN
#                 1991                                                NaN
#                 1992                                                NaN
#                 1993                                                NaN
#                 1994                                                NaN
#
# category              nitrous_oxide_n2o_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent  \
# country_or_area year
# Australia       1990                                       15345.597858
#                 1991                                       14923.405021
#                 1992                                       15293.183355
#                 1993                                       15374.993428
#                 1994                                       15790.426852
#
# category              perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent  \
# country_or_area year
# Australia       1990                                        4607.012919
#                 1991                                        4610.743294
#                 1992                                        4603.282544
#                 1993                                        3315.528376
#                 1994                                        2164.428749
#
# category              sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent  \
# country_or_area year
# Australia       1990                                         211.018511
#                 1991                                         228.944834
#                 1992                                         246.858849
#                 1993                                         264.759156
#                 1994                                         282.640896
#
# category              unspecified_mix_of_hydrofluorocarbons_hfcs_and_perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent
# country_or_area year
# Australia       1990                                                NaN
#                 1991                                                NaN
#                 1992                                                NaN
#                 1993                                                NaN
#                 1994                                                NaN

# %%
def country_plot(nameOfCountry):
    data = table.loc[nameOfCountry]
    plt.plot(data)
    plt.legend(gasnames)
    plt.title(nameOfCountry)

# %%
country_plot('United States of America')

# %%
table2 = pd.pivot_table(df, values='value', index=['category', 'year'], columns=['country_or_area'])
table2.head()
# Out:
# country_or_area                                              Australia  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990  278265.898941
#                                                    1991  279741.639012
#                                                    1992  284766.092718
#                                                    1993  289142.267681
#                                                    1994  293830.709141
#
# country_or_area                                               Austria  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990  62297.165568
#                                                    1991  65903.513308
#                                                    1992  60432.249341
#                                                    1993  60790.757721
#                                                    1994  61189.102505
#
# country_or_area                                                Belarus  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990  100438.095064
#                                                    1991   93649.166141
#                                                    1992   87060.810290
#                                                    1993   75551.755292
#                                                    1994   62402.279083
#
# country_or_area                                                Belgium  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990  119982.503419
#                                                    1991  123130.652897
#                                                    1992  122217.919518
#                                                    1993  121156.964955
#                                                    1994  124426.885710
#
# country_or_area                                              Bulgaria  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990  78197.881257
#                                                    1991  59769.341503
#                                                    1992  56551.593572
#                                                    1993  57203.935518
#                                                    1994  55649.081315
#
# country_or_area                                                 Canada  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990  463493.332388
#                                                    1991  454246.137946
#                                                    1992  468546.458912
#                                                    1993  467607.237235
#                                                    1994  482691.671272
#
# country_or_area                                               Croatia  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990  23390.075209
#                                                    1991  17268.910346
#                                                    1992  16607.134479
#                                                    1993  17081.228023
#                                                    1994  16342.181876
#
# country_or_area                                               Cyprus  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990  4621.007177
#                                                    1991  5107.082887
#                                                    1992  5482.974870
#                                                    1993  5733.674102
#                                                    1994  5977.257105
#
# country_or_area                                          Czech Republic  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990   161662.018872
#                                                    1991   146047.339593
#                                                    1992   141565.719740
#                                                    1993   135588.565573
#                                                    1994   129188.734109
#
# country_or_area                                               Denmark  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990  54306.433336
#                                                    1991  64874.813859
#                                                    1992  58960.311524
#                                                    1993  61038.671244
#                                                    1994  64988.780904
#
# country_or_area                                                    ...             \
# category                                           year            ...
# carbon_dioxide_co2_emissions_without_land_use_l... 1990            ...
#                                                    1991            ...
#                                                    1992            ...
#                                                    1993            ...
#                                                    1994            ...
#
# country_or_area                                          Russian Federation  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990        2.589725e+06
#                                                    1991        2.433188e+06
#                                                    1992        2.013175e+06
#                                                    1993        1.909578e+06
#                                                    1994        1.685495e+06
#
# country_or_area                                              Slovakia  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990  61837.566786
#                                                    1991  53447.440015
#                                                    1992  48979.125765
#                                                    1993  46467.549194
#                                                    1994  43638.490118
#
# country_or_area                                              Slovenia  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990  15088.305046
#                                                    1991  14007.282614
#                                                    1992  14009.398631
#                                                    1993  14303.993650
#                                                    1994  14648.725541
#
# country_or_area                                                  Spain  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990  230154.963134
#                                                    1991  239725.183689
#                                                    1992  248407.160136
#                                                    1993  239938.287256
#                                                    1994  252389.348342
#
# country_or_area                                                Sweden  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990  57546.543252
#                                                    1991  57755.634675
#                                                    1992  57482.064658
#                                                    1993  57425.951447
#                                                    1994  59876.998756
#
# country_or_area                                           Switzerland  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990  44115.534086
#                                                    1991  46144.809539
#                                                    1992  45974.702541
#                                                    1993  43556.276420
#                                                    1994  42613.303737
#
# country_or_area                                                 Turkey  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990  146750.636979
#                                                    1991  152335.174224
#                                                    1992  158571.546484
#                                                    1993  167443.152056
#                                                    1994  164623.553279
#
# country_or_area                                                Ukraine  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990  693024.766560
#                                                    1991  621305.236399
#                                                    1992  577064.259625
#                                                    1993  498504.838992
#                                                    1994  409721.673978
#
# country_or_area                                          United Kingdom  \
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990   596398.473207
#                                                    1991   604652.896878
#                                                    1992   589306.018142
#                                                    1993   574764.752712
#                                                    1994   569458.364876
#
# country_or_area                                          United States of America
# category                                           year
# carbon_dioxide_co2_emissions_without_land_use_l... 1990              5.115095e+06
#                                                    1991              5.064880e+06
#                                                    1992              5.170274e+06
#                                                    1993              5.284759e+06
#                                                    1994              5.377492e+06
#
# [5 rows x 43 columns]

# %%
countryNames = table2.columns.values

# %%
def gas_plot2(nameOfGas):
    data = table2.loc[nameOfGas]
    plt.plot(data)
    plt.legend(countryNames)
    plt.title(nameOfGas)

# %%
gas_plot2(gasnames[0])

# %% [markdown]
# Yay! We can compare all the countries for a given gas.

# %%
def gas_countries_plot3(nameOfGas, namesOfCountries):
    data = table2.loc[nameOfGas]
    data.plot( y = namesOfCountries)
    plt.legend(namesOfCountries)
    plt.title(nameOfGas)
gas_countries_plot3(gasnames[0],countryNames[:4])

# %%
countryNames
# Out:
# array(['Australia', 'Austria', 'Belarus', 'Belgium', 'Bulgaria', 'Canada',
#        'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Estonia',
#        'European Union', 'Finland', 'France', 'Germany', 'Greece',
#        'Hungary', 'Iceland', 'Ireland', 'Italy', 'Japan', 'Latvia',
#        'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malta', 'Monaco',
#        'Netherlands', 'New Zealand', 'Norway', 'Poland', 'Portugal',
#        'Romania', 'Russian Federation', 'Slovakia', 'Slovenia', 'Spain',
#        'Sweden', 'Switzerland', 'Turkey', 'Ukraine', 'United Kingdom',
#        'United States of America'], dtype=object)
